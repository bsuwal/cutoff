# %%
include("cutoff.jl")

N = 5
X₀ = rand(Uniform(-1, 1), N)
num_chains = 100
# Dist = Uniform(-1/√N, 1/√N)
Dist = Normal(0.0, 1)
# Dist = Normal(0.0, 1/√N)
activation = σ
# activation = tanh
step_size = 0.001
num_steps = 20
forward = false

Exp = Experiment(X₀, N, num_chains, Dist, activation, step_size, num_steps, forward)
run_and_plot_tvd_experiment(Exp, verbose=false)
